# %%
from build123d import *

# The viewer is interactive

hello_world = Box(10,10,10)
hello_world
# Out:
# Box at 0x1c84bc72450, label(), #children(0)

# %%
from build123d import *

L,W,H,HOLE_RADIUS = 10,10,10,2

with BuildPart() as box_with_hole:
    Box(length=L,width=W,height=H)
    Cylinder(radius=HOLE_RADIUS, height=H, mode=Mode.SUBTRACT)
    
box_with_hole.part
# Out:
# Part at 0x1c84a219050, label(), #children(0)
