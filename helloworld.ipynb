# %%
from build123d import *

# The viewer is interactive in vscode

hello_world_part = Box(10,10,10)
hello_world_part
# Out:
# Box at 0x192f5986790, label(), #children(0)

# %%
from build123d import *
part = Box(10,10,10)
part
# Out:
# Box at 0x1928c538250, label(), #children(0)
