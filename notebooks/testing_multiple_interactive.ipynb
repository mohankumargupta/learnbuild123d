# %%
from build123d import *
box = Box(10,10,10)
box
# Out:
# Box at 0x165d4d1fe10, label(), #children(0)

# %%
from build123d import *
cylinder = Cylinder(radius=10, height=50)
cylinder
# Out:
# Cylinder at 0x165ae7fec50, label(), #children(0)
